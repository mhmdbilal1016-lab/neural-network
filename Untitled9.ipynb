# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import base64
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, classification_report
from sklearn.preprocessing import (
    LabelEncoder, StandardScaler, MinMaxScaler,
    MaxAbsScaler, PowerTransformer
)
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.experimental import enable_iterative_imputer  # noqa
from sklearn.impute import IterativeImputer
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest, f_classif, f_regression
from sklearn.ensemble import (
    RandomForestClassifier, IsolationForest
)
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.cluster import DBSCAN
from sklearn.utils import resample
from imblearn.over_sampling import SMOTE
from scipy import stats
from scipy.stats.mstats import winsorize

# %%
df=pd.read_excel("FuelConsumptionCo2.csv.xlsx")

# %%
df.shape
# Out:
# (1067, 12)

# %%
df.head()
# Out:
#    MODELYEAR Brands VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION FUELTYPE  \
# 0       2014  ACURA      COMPACT         2.0          4          AS5        Z
# 1       2014  ACURA      COMPACT         2.4          4           M6        Z
# 2       2014  ACURA      COMPACT         1.5          4          AV7        Z
# 3       2014  ACURA    SUV_SMALL         3.5          6          AS6        Z
# 4       2014  ACURA    SUV_SMALL         3.5          6          AS6        Z
#
#    FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# 0                   9.9                  6.7                   8.5
# 1                  11.2                  7.7                   9.6
# 2                   6.0                  5.8                   5.9
# 3                  12.7                  9.1                  11.1
# 4                  12.1                  8.7                  10.6
#
#    FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                        33           196
# 1                        29           221
# 2                        48           136
# 3                        25           255
# 4                        27           244

# %%
df.tail()
# Out:
#       MODELYEAR Brands  VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION  \
# 1062       2014  VOLVO     SUV_SMALL         3.0          6          AS6
# 1063       2014  VOLVO     SUV_SMALL         3.2          6          AS6
# 1064       2014  VOLVO     SUV_SMALL         3.0          6          AS6
# 1065       2014  VOLVO     SUV_SMALL         3.2          6          AS6
# 1066       2014  VOLVO  SUV_STANDARD         3.2          6          AS6
#
#      FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 1062        X                  13.4                  9.8
# 1063        X                  13.2                  9.5
# 1064        X                  13.4                  9.8
# 1065        X                  12.9                  9.3
# 1066        X                  14.9                 10.2
#
#       FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 1062                  11.8                        24           271
# 1063                  11.5                        25           264
# 1064                  11.8                        24           271
# 1065                  11.3                        25           260
# 1066                  12.8                        22           294

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   MODELYEAR                 1067 non-null   int64
#  1   Brands                    1067 non-null   object
#  2   VEHICLECLASS              1067 non-null   object
#  3   ENGINESIZE                1067 non-null   float64
#  4   CYLINDERS                 1067 non-null   int64
#  5   TRANSMISSION              1067 non-null   object
#  6   FUELTYPE                  1067 non-null   object
#  7   FUELCONSUMPTION_CITY      1067 non-null   float64
#  8   FUELCONSUMPTION_HWY       1067 non-null   float64
#  9   FUELCONSUMPTION_COMB      1067 non-null   float64
#  10  FUELCONSUMPTION_COMB_MPG  1067 non-null   int64
#  11  CO2EMISSIONS              1067 non-null   int64
# dtypes: float64(4), int64(4), object(4)
# memory usage: 100.2+ KB

# %%
df.describe()
# Out:
#        MODELYEAR   ENGINESIZE    CYLINDERS  FUELCONSUMPTION_CITY  \
# count     1067.0  1067.000000  1067.000000           1067.000000
# mean      2014.0     3.346298     5.794752             13.296532
# std          0.0     1.415895     1.797447              4.101253
# min       2014.0     1.000000     3.000000              4.600000
# 25%       2014.0     2.000000     4.000000             10.250000
# 50%       2014.0     3.400000     6.000000             12.600000
# 75%       2014.0     4.300000     8.000000             15.550000
# max       2014.0     8.400000    12.000000             30.200000
#
#        FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# count          1067.000000           1067.000000               1067.000000
# mean              9.474602             11.580881                 26.441425
# std               2.794510              3.485595                  7.468702
# min               4.900000              4.700000                 11.000000
# 25%               7.500000              9.000000                 21.000000
# 50%               8.800000             10.900000                 26.000000
# 75%              10.850000             13.350000                 31.000000
# max              20.500000             25.800000                 60.000000
#
#        CO2EMISSIONS
# count   1067.000000
# mean     256.228679
# std       63.372304
# min      108.000000
# 25%      207.000000
# 50%      251.000000
# 75%      294.000000
# max      488.000000

# %%
df.isna().sum()
# Out:
# MODELYEAR                   0
# Brands                      0
# VEHICLECLASS                0
# ENGINESIZE                  0
# CYLINDERS                   0
# TRANSMISSION                0
# FUELTYPE                    0
# FUELCONSUMPTION_CITY        0
# FUELCONSUMPTION_HWY         0
# FUELCONSUMPTION_COMB        0
# FUELCONSUMPTION_COMB_MPG    0
# CO2EMISSIONS                0
# dtype: int64

# %%
df.describe()
# Out:
#        MODELYEAR   ENGINESIZE    CYLINDERS  FUELCONSUMPTION_CITY  \
# count     1067.0  1067.000000  1067.000000           1067.000000
# mean      2014.0     3.346298     5.794752             13.296532
# std          0.0     1.415895     1.797447              4.101253
# min       2014.0     1.000000     3.000000              4.600000
# 25%       2014.0     2.000000     4.000000             10.250000
# 50%       2014.0     3.400000     6.000000             12.600000
# 75%       2014.0     4.300000     8.000000             15.550000
# max       2014.0     8.400000    12.000000             30.200000
#
#        FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# count          1067.000000           1067.000000               1067.000000
# mean              9.474602             11.580881                 26.441425
# std               2.794510              3.485595                  7.468702
# min               4.900000              4.700000                 11.000000
# 25%               7.500000              9.000000                 21.000000
# 50%               8.800000             10.900000                 26.000000
# 75%              10.850000             13.350000                 31.000000
# max              20.500000             25.800000                 60.000000
#
#        CO2EMISSIONS
# count   1067.000000
# mean     256.228679
# std       63.372304
# min      108.000000
# 25%      207.000000
# 50%      251.000000
# 75%      294.000000
# max      488.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(115)

# %%
df.drop(["MODELYEAR","FUELCONSUMPTION_COMB_MPG","Brands"],axis=1,inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(180)

# %%
df.drop_duplicates(inplace=True)

# %%
cat_cols=df.select_dtypes(include="object").columns.tolist()
num_cols=df.select_dtypes(exclude="object").columns.tolist()
print("Categorical Columns:", cat_cols)
print("Numerical Columns:", num_cols)
# Out:
# Categorical Columns: ['VEHICLECLASS', 'TRANSMISSION', 'FUELTYPE']
# Numerical Columns: ['ENGINESIZE', 'CYLINDERS', 'FUELCONSUMPTION_CITY', 'FUELCONSUMPTION_HWY', 'FUELCONSUMPTION_COMB', 'CO2EMISSIONS']

# %%
le = LabelEncoder()
for col in cat_cols:
    df[col] = le.fit_transform(df[col])

print("Label Encoding applied on:", cat_cols)
# Out:
# Label Encoding applied on: ['VEHICLECLASS', 'TRANSMISSION', 'FUELTYPE']

# %%
for i in num_cols:
  sns.boxplot(df[i])
  plt.title(i)
  plt.show()

# %%
def cap_outliers(data, columns, factor=1.5):
    for col in columns:
        Q1 = data[col].quantile(0.25)
        Q3 = data[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - factor * IQR
        upper = Q3 + factor * IQR
        data[col] = data[col].clip(lower, upper)
    return data

data = cap_outliers(df, num_cols)

# %%
for i in num_cols:
  sns.boxplot(df[i])
  plt.title(i)
  plt.show()

# %%
x=df.drop("CO2EMISSIONS",axis=1)
y=df["CO2EMISSIONS"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential([
    Dense(64, activation="relu", input_shape=(x_train_scaled.shape[1],)),
    Dense(32, activation="relu"),
    Dense(1)
])

model.compile(optimizer="adam", loss="mse", metrics=["mae"])

# Train
history = model.fit(x_train_scaled, y_train,
                    validation_split=0.2,
                    epochs=100,
                    batch_size=32,
                    verbose=1)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 68202.7109 - mae: 253.7105 - val_loss: 65435.9570 - val_mae: 247.8212
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 66324.8672 - mae: 250.4224 - val_loss: 64588.5078 - val_mae: 246.2041
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 65568.3438 - mae: 248.8282 - val_loss: 63296.2969 - val_mae: 243.7037
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 63696.4961 - mae: 245.7038 - val_loss: 61384.2734 - val_mae: 239.9379
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 63345.3047 - mae: 244.5969 - val_loss: 58569.0352 - val_mae: 234.2796
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 58469.1562 - mae: 234.7819 - val_loss: 54670.0039 - val_mae: 226.1867
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 56619.7539 - mae: 231.2279 - val_loss: 49622.7109 - val_mae: 215.1644
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 49510.9180 - mae: 214.8692 - val_loss: 43502.5195 - val_mae: 200.7242
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 44521.8594 - mae: 203.6411 - val_loss: 36583.0703 - val_mae: 182.7012
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 36415.4805 - mae: 182.0547 - val_loss: 29545.3594 - val_mae: 161.9177
# Epoch 11/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 29966.6465 - mae: 163.1675 - val_loss: 23001.8379 - val_mae: 139.3341
# Epoch 12/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23704.6348 - mae: 140.8513 - val_loss: 17569.4199 - val_mae: 117.4373
# Epoch 13/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18905.5352 - mae: 121.5395 - val_loss: 13802.7549 - val_mae: 100.4018
# Epoch 14/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 14528.6426 - mae: 103.0588 - val_loss: 11616.2402 - val_mae: 91.0316
# Epoch 15/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13620.3350 - mae: 98.0864 - val_loss: 10503.0723 - val_mae: 86.3943
# Epoch 16/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11468.0117 - mae: 91.2504 - val_loss: 9891.9375 - val_mae: 84.1094
# Epoch 17/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10701.5576 - mae: 86.9192 - val_loss: 9431.7744 - val_mae: 82.6568
# Epoch 18/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10207.6201 - mae: 85.2097 - val_loss: 8966.4756 - val_mae: 80.8372
# Epoch 19/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9619.9893 - mae: 82.1464 - val_loss: 8469.1875 - val_mae: 78.6554
# Epoch 20/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9057.4551 - mae: 80.3621 - val_loss: 7983.9614 - val_mae: 76.3953
# Epoch 21/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8157.7524 - mae: 76.6337 - val_loss: 7475.3467 - val_mae: 73.8673
# Epoch 22/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7730.2139 - mae: 73.3859 - val_loss: 6997.9463 - val_mae: 71.4005
# Epoch 23/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7084.0649 - mae: 70.4421 - val_loss: 6506.6357 - val_mae: 68.6680
# Epoch 24/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6572.0894 - mae: 67.2634 - val_loss: 6056.5723 - val_mae: 66.0897
# Epoch 25/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6368.5352 - mae: 66.5325 - val_loss: 5591.5132 - val_mae: 63.2823
# Epoch 26/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5234.2388 - mae: 59.8003 - val_loss: 5176.7969 - val_mae: 60.6037
# Epoch 27/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5081.8262 - mae: 59.7294 - val_loss: 4735.4487 - val_mae: 57.6876
# Epoch 28/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4830.0981 - mae: 57.4439 - val_loss: 4330.9702 - val_mae: 54.9441
# Epoch 29/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4852.9570 - mae: 57.0193 - val_loss: 3971.3406 - val_mae: 52.3974
# Epoch 30/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4222.5796 - mae: 53.2435 - val_loss: 3622.6375 - val_mae: 49.7534
# Epoch 31/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3697.0374 - mae: 49.4700 - val_loss: 3280.5967 - val_mae: 47.0495
# Epoch 32/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3301.1016 - mae: 46.4064 - val_loss: 2989.1445 - val_mae: 44.6717
# Epoch 33/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3055.0435 - mae: 44.9634 - val_loss: 2714.5327 - val_mae: 42.3786
# Epoch 34/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3064.1641 - mae: 44.7715 - val_loss: 2453.7246 - val_mae: 40.1165
# Epoch 35/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2534.0044 - mae: 40.3129 - val_loss: 2243.3376 - val_mae: 38.2286
# Epoch 36/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2300.3367 - mae: 37.6125 - val_loss: 2033.2234 - val_mae: 36.3687
# Epoch 37/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2087.6152 - mae: 35.5974 - val_loss: 1859.8479 - val_mae: 34.7944
# Epoch 38/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1983.4062 - mae: 34.8237 - val_loss: 1697.6937 - val_mae: 33.2183
# Epoch 39/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1789.5923 - mae: 33.2876 - val_loss: 1557.9039 - val_mae: 31.7636
# Epoch 40/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1744.8578 - mae: 32.4018 - val_loss: 1428.9128 - val_mae: 30.3067
# Epoch 41/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1600.9169 - mae: 31.2924 - val_loss: 1318.6501 - val_mae: 29.1064
# Epoch 42/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1484.4519 - mae: 29.9858 - val_loss: 1222.4615 - val_mae: 27.9897
# Epoch 43/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1289.2352 - mae: 27.6851 - val_loss: 1142.3058 - val_mae: 27.0230
# Epoch 44/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1276.7072 - mae: 27.4612 - val_loss: 1065.8900 - val_mae: 26.1230
# Epoch 45/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1127.3829 - mae: 26.0595 - val_loss: 997.4712 - val_mae: 25.2799
# Epoch 46/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1090.9669 - mae: 25.5501 - val_loss: 939.4822 - val_mae: 24.5514
# Epoch 47/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 974.4802 - mae: 24.2831 - val_loss: 888.7491 - val_mae: 23.7758
# Epoch 48/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 955.7296 - mae: 24.0956 - val_loss: 838.2827 - val_mae: 23.1323
# Epoch 49/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1006.0319 - mae: 24.7591 - val_loss: 792.7181 - val_mae: 22.4195
# Epoch 50/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 907.2797 - mae: 23.4871 - val_loss: 754.5717 - val_mae: 21.8726
# Epoch 51/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 820.8195 - mae: 22.3543 - val_loss: 724.3693 - val_mae: 21.3017
# Epoch 52/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 794.2791 - mae: 21.9420 - val_loss: 691.8762 - val_mae: 20.8437
# Epoch 53/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 773.9752 - mae: 21.6847 - val_loss: 657.0729 - val_mae: 20.4084
# Epoch 54/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 758.0424 - mae: 21.7197 - val_loss: 635.3343 - val_mae: 19.8651
# Epoch 55/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 748.4185 - mae: 21.5976 - val_loss: 605.2687 - val_mae: 19.4689
# Epoch 56/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 697.0092 - mae: 20.8299 - val_loss: 580.2972 - val_mae: 18.9930
# Epoch 57/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 636.4086 - mae: 19.5858 - val_loss: 555.9767 - val_mae: 18.4911
# Epoch 58/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 577.2511 - mae: 18.6012 - val_loss: 530.1755 - val_mae: 18.0556
# Epoch 59/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 585.0896 - mae: 18.9886 - val_loss: 509.6774 - val_mae: 17.6283
# Epoch 60/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 584.4565 - mae: 18.8043 - val_loss: 490.2877 - val_mae: 17.2071
# Epoch 61/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 575.5245 - mae: 18.6272 - val_loss: 467.9081 - val_mae: 16.8632
# Epoch 62/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 497.6670 - mae: 17.3047 - val_loss: 452.9058 - val_mae: 16.4794
# Epoch 63/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 536.0935 - mae: 18.1668 - val_loss: 440.1197 - val_mae: 16.2488
# Epoch 64/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 455.6323 - mae: 16.6246 - val_loss: 419.9394 - val_mae: 15.8829
# Epoch 65/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 462.6872 - mae: 16.6806 - val_loss: 408.6952 - val_mae: 15.6085
# Epoch 66/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 456.4974 - mae: 16.8918 - val_loss: 396.0266 - val_mae: 15.3196
# Epoch 67/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 449.9483 - mae: 16.5318 - val_loss: 382.4021 - val_mae: 15.0448
# Epoch 68/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 423.8817 - mae: 16.1835 - val_loss: 368.6012 - val_mae: 14.7844
# Epoch 69/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 378.3338 - mae: 15.1347 - val_loss: 355.3198 - val_mae: 14.4600
# Epoch 70/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 414.2380 - mae: 15.9627 - val_loss: 346.2820 - val_mae: 14.2314
# Epoch 71/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 359.9869 - mae: 14.5587 - val_loss: 339.3120 - val_mae: 14.0927
# Epoch 72/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 382.6308 - mae: 15.3266 - val_loss: 323.1789 - val_mae: 13.7325
# Epoch 73/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 369.9563 - mae: 14.7124 - val_loss: 316.3229 - val_mae: 13.5785
# Epoch 74/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 345.5892 - mae: 14.5345 - val_loss: 304.4913 - val_mae: 13.2782
# Epoch 75/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 314.4427 - mae: 13.7133 - val_loss: 296.9637 - val_mae: 13.0354
# Epoch 76/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 326.4045 - mae: 13.7726 - val_loss: 287.8542 - val_mae: 12.7615
# Epoch 77/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 293.8250 - mae: 13.2587 - val_loss: 280.1363 - val_mae: 12.5820
# Epoch 78/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 323.6694 - mae: 13.8011 - val_loss: 269.6107 - val_mae: 12.3872
# Epoch 79/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 266.5612 - mae: 12.5284 - val_loss: 263.1922 - val_mae: 12.1347
# Epoch 80/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 269.9240 - mae: 12.5414 - val_loss: 253.3245 - val_mae: 11.8808
# Epoch 81/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 256.5462 - mae: 12.2331 - val_loss: 247.4237 - val_mae: 11.7212
# Epoch 82/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 258.6050 - mae: 12.2225 - val_loss: 239.0162 - val_mae: 11.5494
# Epoch 83/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 250.7864 - mae: 11.9019 - val_loss: 232.4341 - val_mae: 11.3463
# Epoch 84/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 241.8683 - mae: 11.8514 - val_loss: 226.3272 - val_mae: 11.1752
# Epoch 85/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 240.5441 - mae: 11.5734 - val_loss: 219.3741 - val_mae: 10.9807
# Epoch 86/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 236.7610 - mae: 11.5065 - val_loss: 215.8644 - val_mae: 10.9029
# Epoch 87/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 229.6745 - mae: 11.5961 - val_loss: 207.0685 - val_mae: 10.6919
# Epoch 88/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 208.3153 - mae: 10.7702 - val_loss: 201.1526 - val_mae: 10.5078
# Epoch 89/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 207.9090 - mae: 10.7361 - val_loss: 197.1143 - val_mae: 10.3464
# Epoch 90/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 208.8571 - mae: 10.6457 - val_loss: 192.5652 - val_mae: 10.2426
# Epoch 91/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 183.9425 - mae: 9.8689 - val_loss: 185.6903 - val_mae: 10.0022
# Epoch 92/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 187.2365 - mae: 10.0694 - val_loss: 183.5595 - val_mae: 9.8779
# Epoch 93/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 186.2631 - mae: 10.0147 - val_loss: 177.6413 - val_mae: 9.7511
# Epoch 94/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 164.4149 - mae: 9.4439 - val_loss: 174.5880 - val_mae: 9.5924
# Epoch 95/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 172.0818 - mae: 9.7024 - val_loss: 170.1638 - val_mae: 9.4483
# Epoch 96/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 162.3139 - mae: 9.1835 - val_loss: 165.8593 - val_mae: 9.3148
# Epoch 97/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 180.6363 - mae: 9.6743 - val_loss: 164.6132 - val_mae: 9.1730
# Epoch 98/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 162.0155 - mae: 9.1082 - val_loss: 158.7058 - val_mae: 9.0845
# Epoch 99/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 156.4024 - mae: 8.8417 - val_loss: 156.1615 - val_mae: 8.9479
# Epoch 100/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 148.6586 - mae: 8.8686 - val_loss: 154.0957 - val_mae: 8.8025

# %%
loss, mae = model.evaluate(x_test_scaled, y_test, verbose=0)
print(f"Test MAE: {mae:.2f} g/km CO2")
# Out:
# Test MAE: 8.54 g/km CO2

# %%
loss=pd.DataFrame(history.history)
loss.plot()
# Out:
# <Axes: >

# %%
model.save("my_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import joblib
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
from google.colab import files


files.download("my_model.h5")
